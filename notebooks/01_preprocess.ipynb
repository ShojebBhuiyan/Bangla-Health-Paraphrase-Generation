# %% [markdown]
# # 01 - Data Preprocessing

# %%
import sys
from pathlib import Path
PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT))

from src.common.checkpointing import is_done
from src.common.config import load_config
from src.pipeline.preprocess import run_preprocess

cfg = load_config(PROJECT_ROOT / 'configs' / 'experiment_config.yaml')
if not is_done('preprocess', cfg):
    run_preprocess(cfg)
else:
    print('Preprocess already complete')
