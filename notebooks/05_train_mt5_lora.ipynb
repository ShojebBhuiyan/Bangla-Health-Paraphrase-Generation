# %% [markdown]
# # 05 - Train mT5 + LoRA

# %%
import sys
from pathlib import Path
PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT))

from src.common.checkpointing import is_done
from src.common.config import load_config
from src.models.mt5_lora import run_mt5_lora

cfg = load_config(PROJECT_ROOT / 'configs' / 'experiment_config.yaml')
if not is_done('train_mt5_lora', cfg):
    run_mt5_lora(cfg)
else:
    print('mT5 LoRA training already complete')
