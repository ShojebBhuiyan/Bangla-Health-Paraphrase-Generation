# %% [markdown]
# # 06 - Train Baselines

# %%
import sys
from pathlib import Path
PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT))

from src.common.checkpointing import is_done
from src.common.config import load_config
from src.models.mt5_baseline import run_mt5_baseline
from src.models.mbart_baseline import run_mbart_baseline

cfg = load_config(PROJECT_ROOT / 'configs' / 'experiment_config.yaml')
if not is_done('train_mt5_baseline', cfg):
    run_mt5_baseline(cfg)
if not is_done('train_mbart_baseline', cfg):
    run_mbart_baseline(cfg)
