# %% [markdown]
# # 02 - EDA Report

# %%
import sys
from pathlib import Path
PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT))

from src.common.checkpointing import is_done
from src.common.config import load_config
from src.reports.eda_report import render_eda_report

cfg = load_config(PROJECT_ROOT / 'configs' / 'experiment_config.yaml')
if not is_done('eda_report', cfg):
    render_eda_report(cfg)
else:
    print('EDA report already complete')
